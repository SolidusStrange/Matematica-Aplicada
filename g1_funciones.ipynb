# %% [markdown]
# <a href="https://colab.research.google.com/github/SolidusStrange/Matematica-Aplicada/blob/main/g1_funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTAR
import matplotlib.pyplot as plt
import numpy as np

#VARIABLE INDEPENDIENTES ENTRE 0 Y 6, INTERVALO 0.01
x = np.arange(0, 6, 0.01)

#FUNCION
y = 120*x+2000

#LINEAS PARA GRÁFICO
plt.plot(x,y)
#EJES (X) (Y) PARÁMETROS
plt.axis([0,6,2000,2800])

#NOMBRE EJE X
plt.xlabel("Energia utilizada ({kwh})")

#NOMBRE EJE Y
plt.ylabel("Costo para usuario ({$})")
plt.title("Funcion de Ejemplo")
plt.grid(True)

# %% [markdown]
# # Problema 1

# %% [markdown]
# Una red transmite datos a $100$ megabits por segundo. Crea una función utilizando *Python* que permita calcular la cantidad de datos transmitidos en una cierta cantidad de tiempo (en segundos). Luego utiliza la función y calcula cuántos datos se transmiten en:
#
# * $45$ segundos
# * $1,5$ minutos
# * $1$ hora

# %% [markdown]
# **Respuesta:** Primero hay que crear la función determinando cuál es la variable dependiente e independiente:
# - Variable independiente ($t$): tiempo en segundos
# - Variable dependiente $m(t)$: 100mbs transmitidos por segundo
#
# Luego se realizan los cálculos teniendo en cuenta que 100mbs son por segundo → 100 * $t$
# - Por lo que la función sería: $m(t)$: 100t

# %%
def m(t):
  return 100*t

# 45 segundos
# 1,5 minutos = 90 segundos
# 1 hora = 60 min = 3600 segundos

print(f"A los 45 segundos se transmiten {m(45):.0f} megabits")
print(f"A los 1.5 minutos segundos se transmiten {m(1.5*60):.0f} megabits")
print(f"A la hora se transmiten {m(60*60):.0f} megabits")
# Out:
# A los 45 segundos se transmiten 4500 megabits
# A los 1.5 minutos segundos se transmiten 9000 megabits
# A la hora se transmiten 360000 megabits

# %% [markdown]
# # Problema 2

# %% [markdown]
# Utilizando la función definida en el problema $1$, genera un listado que muestre los datos transmitidos para tiempos desde $0$ hasta $1.000$ segundos con incrementos de $100$ segundos.

# %%
def m(t):
  return 100*t

for t in range(0, 1001, 100):
    print(f"A los {t} segundos se trasmiten {m(t)} megabits")
# Out:
# A los 0 segundos se trasmiten 0 megabits
# A los 100 segundos se trasmiten 10000 megabits
# A los 200 segundos se trasmiten 20000 megabits
# A los 300 segundos se trasmiten 30000 megabits
# A los 400 segundos se trasmiten 40000 megabits
# A los 500 segundos se trasmiten 50000 megabits
# A los 600 segundos se trasmiten 60000 megabits
# A los 700 segundos se trasmiten 70000 megabits
# A los 800 segundos se trasmiten 80000 megabits
# A los 900 segundos se trasmiten 90000 megabits
# A los 1000 segundos se trasmiten 100000 megabits

# %% [markdown]
# # Problema 3

# %% [markdown]
# La **latencia** de una red corresponde al tiempo que tarda un paquete de datos en viajar desde el punto de origen al destino. En otras palabras, es el tiempo que transcurre desde que se envía una solicitud de un dispositivo hasta que se recibe una respuesta del servidor u otro dispositivo.
#
# La latencia puede verse afectada por la velocidad de transmisión de los datos a través de los cables o conexiones inalámbricas, la distancia física entre los dispositivos, el tiempo que tarda un computador en procesar o reenviar los datos, etc.
#
# En redes de comunicación, como las videoconferencias, juegos en línea y transmisión de datos en tiempo real, es deseable una baja latencia, de lo contrario pueden existir retrasos en la comunicación y afectar negativamente la experiencia del usuario.

# %% [markdown]
# Según el contexto mencionado, crea una función en *Python* que permita calcular la **latencia real** de una red dada una latencia estimada. Suponga que la latencia real es un $20\%$ mayor a la latencia estimada.
#
# Calcule la latencia real para una latencia estimada de:
#
# a)   $200$ milisegundos.
#
# b)   $149$ milisegundos.
#
# c)   $74$ milisegundos.

# %%
#l(t): latencia real
#(t): latencia estimada
preguntas = [200, 149, 74]

def latencia_real(t):
    return 1.2*t

for t in preguntas:
    print(f"Para {t} milisegundos hay una latencia real de {latencia_real(t):.0f} ms")
# Out:
# Para 200 milisegundos hay una latencia real de 240 ms
# Para 149 milisegundos hay una latencia real de 179 ms
# Para 74 milisegundos hay una latencia real de 89 ms

# %% [markdown]
# # Problema 4

# %% [markdown]
# Como parte de un proyecto de mejora, en el año $2021$ se instaló un cable de fibra óptica que une España con EEUU. El cable tiene un largo de $6.600$ $km$ y fue colocado por un barco a una velocidad de $1,85$ $km/h$.
#
#
#
# 1.   Determine la forma algebraica de la función que permite determinar el largo del cable instalado (en km) a partir del tiempo transcurrido (en horas). Utilice la instrucción *def* para definir la función en *Python*.
# 2.   Defina variable dependiente e independiente, indicando unidad de medida.
# 3.   Determine el dominio contextualizado de la función.
# 4.   Grafique la función utilizando la biblioteca *Matplotlib* considerando el dominio contextualizado.
# 5.   ¿Cuántos metros de cable se instalaron al transcurrir $148$ horas? ¿Y transcurridas $2.300$ horas?
# 6.   Si se han instalado $3.480$ kilometros de cable, ¿cuántas horas llevan de trabajo?
# 7.   ¿Cuánto tiempo transcurrió para que se completara la obra?

# %%
#Pregunta 4.1: 
# Largo instalado en función del tiempo
def l(t):
    return 1.85 * t   # km

# Tiempo necesario para instalar un largo L
def t_necesario(L):
    return L / 1.85   # horas

print(f"Para instalar un cable de 6600km se necesita un tiempo transcurrido de {t_necesario(6600):.2f} km/h")
# Out:
# Para instalar un cable de 6600km se necesita un tiempo transcurrido de 3567.57 km/h

# %% [markdown]
# **Pregunta 4.2:** Defina variable dependiente e independiente, indicando unidad de medida.
#
# Variable independiente:
# - t = tiempo transcurrido (horas).
#
# Variable dependiente:
# - L(t) = largo instalado (kilómetros).

# %% [markdown]
# **Pregunta 4.3**: Determine el dominio contextualizado de la función
#
# **R:** Dom L(t): [0, 3567.57] #Todos los valores posibles de t. (cuando se completa la obra)

# %%
#PREGUNTA 4.4

import matplotlib.pyplot as plt
import numpy as np 

# Definimos las funciones
def L(t):
    return 1.85 * t 

# Rango de tiempo (0 a 15 minutos)
t = np.arange(0, 3567.57, 0.1)  #np.arange(inicio, fin, paso)

# Graficar ambas funciones
plt.plot(t, L(t), label="Largo instalado en (km) (L(t) = 1.85*t)") #dibuja una curva x = t, y = f(t)
plt.axhline(y=6600, color='r', linestyle='--', label="Distancia en 6600 km")

# Ajustamos los ejes: [xmin, xmax, ymin, ymax]
plt.axis([0, 5000, 0, 10000])  

plt.legend() #muestra la leyenda con los nombres que pusimos en label
plt.xlabel("Tiempo transcurrido (horas)") #nombre del eje x
plt.ylabel("Largo instalado (kms)") #nombre del eje y
plt.title("Largo instalado del cable a partir del tiempo") #título del gráfico
plt.grid(True) #activa la rejilla (cuadrícula) para ver mejor los valores
plt.show() #muestra el grafico. a veces no lo muestra sin este codigo
# Ajustamos los ejes: [xmin, xmax, ymin, ymax]

# %% [markdown]
# **Pregunta 4.5**: ¿Cuántos metros de cable se instalaron al transcurrir $148$ horas? ¿Y transcurridas $2.300$ horas?

# %%
# Definimos las funciones
def L(t):
    return 1.85 * t 

print(f"La cantidad de metros de cable que se instalarán al transcurrir 148 hrs es {L(148):.2f} kms") 
print(f"La cantidad de metros de cable que se instalarán al transcurrir 2300 hrs es {L(2300):.2f} kms")
# Out:
# La cantidad de metros de cable que se instalarán al transcurrir 148 hrs es 273.80 kms
# La cantidad de metros de cable que se instalarán al transcurrir 2300 hrs es 4255.00 kms

# %% [markdown]
# **Pregunta 4.6:** Si se han instalado $3.480$ kilometros de cable, ¿cuántas horas llevan de trabajo?

# %%
# Definimos las funciones
def L(t):
    return 1.85 * t 

def t_necesario(L):
    return L / 1.85
    

cable = 3480
print(f"La cantidad de horas que tomó para instalar {cable} kilometros de cable es de {t_necesario(cable):.0f} horas")
# Out:
# La cantidad de horas que tomó para instalar 3480 kilometros de cable es de 1881 horas

# %% [markdown]
# **Pregunta 4.7:** ¿Cuánto tiempo transcurrió para que se completara la obra?

# %%
# Definimos las funciones
def L(t):
    return 1.85 * t 

def t_necesario(L):
    return L / 1.85
    
cable = 6600
print(f"La cantidad de horas que tomó para instalar {cable} kilometros de cable es de {t_necesario(cable):.0f} horas")
# Out:
# La cantidad de horas que tomó para instalar 6600 kilometros de cable es de 3568 horas

# %% [markdown]
# # Problema 5

# %% [markdown]
# Un turista ha llegado a Santiago y desea conocer algunos lugares de la ciudad. Ha decidido visitar el Palacio de la Moneda y desde ahí trasladarse al centro comercial "Costanera Center", utilizando algún medio de transporte que ofrece la ciudad.
#
# Si se traslada en metro deberá abordar en estación La Moneda y bajar en la estación Tobalaba ($9$ estaciones). La función $f(t)$ permite calcular la distancia recorrida utilizando el metro (en kilómetros) transcurridos $t$ minutos.
#
# $$f(t) = 0,4t$$
#
# Si se traslada en bus, el turista podrá observar la ciudad y otros atractivos en su viaje. La función $g(t)$ permite calcular la distancia recorrida en bus (en kilómetros) transcurridos $t$ minutos.
#
# $$g(t) = 0,3t$$
#
# Según la información anterior:
#
# 1. Grafique ambas funciones, indicando el nombre de cada eje junto con su unidad de medida. Para realizar el gráfico utilice la biblioteca *Matplotlib*.
# 2.  Si se sabe que el metro se demora $1,2$ minutos en llegar desde una estación a otra y espera $30$ segundos en cada estación, indique el dominio contextualizado para $f(t)$.
# 3. Mediante análisis gráfico, indique cuál medio de transporte es más conveniente en términos de tiempo, para el turista. Justifique.
# 4.  Si se sabe que desde estación La Moneda hasta Tobalaba son aproximadamente $6$ kilómetros ¿cuántos tiempo tardará el turista en llegar a su destino con cada una de las opciones?

# %% [markdown]
# **#PREGUNTA 5.1:** Grafique ambas funciones, indicando el nombre de cada eje junto con su unidad de medida. Para realizar el gráfico utilice la biblioteca *Matplotlib*

# %%
#PREGUNTA NÚMERO 5.1
import matplotlib.pyplot as plt #es el módulo de gráficas en Python. Se abrevia como plt por convención.
import numpy as np #es una librería para trabajar con vectores, matrices y rangos numéricos. Se abrevia np

# Definimos las funciones
def f(t):
    return 0.4 * t  # metro

def g(t):
    return 0.3 * t  # bus

# Rango de tiempo (0 a 15 minutos)
t = np.arange(0, 15, 0.1)  #np.arange(inicio, fin, paso)

# Graficar ambas funciones
plt.plot(t, f(t), label="Metro (f(t) = 0.4t)") #dibuja una curva x = t, y = f(t)
plt.plot(t, g(t), label="Bus (g(t) = 0.3t)")
plt.axhline(y=6, color='r', linestyle='--', label="Distancia 6 km")
plt.legend() #muestra la leyenda con los nombres que pusimos en label
plt.xlabel("Tiempo en minutos") #nombre del eje x
plt.ylabel("Distancia recorrida en KM") #nombre del eje y
plt.title("Recorrido del Metro") #título del gráfico
plt.grid(True) #activa la rejilla (cuadrícula) para ver mejor los valores
plt.show() #muestra el grafico. a veces no lo muestra sin este codigo
# Ajustamos los ejes: [xmin, xmax, ymin, ymax]

# %% [markdown]
# **#PREGUNTA 5.2** Si se sabe que el metro se demora $1,2$ minutos en llegar desde una estación a otra y espera $30$ segundos en cada estación, indique el dominio contextualizado para $f(t)$
#
# **R**: Dominio contextualizado para f(𝑡)
# Entre La Moneda y Tobalaba son 9 tramos de viaje (de una estación a la siguiente).
# *Tiempo en movimiento:* 9×1,2=10,8 min
#
# *Esperas en estaciones intermedias:* hay 8 paradas intermedias → 8×0,5=4 min
#
# *Tiempo total del recorrido en metro:* 10,8+4 → 14,8 min
#
# *Dom f(t): [0, 14.8] minutos*

# %% [markdown]
# **#PREGUNTA 5.3**
# ¿Qué medio conviene en tiempo?
#
# **R**: La recta del metro tiene mayor pendiente (0,4 km/min) que la del bus (0,3 km/min), por lo que para una misma distancia el metro alcanza antes esa distancia. *Conviene el metro en términos de tiempo*.

# %% [markdown]
# **#PREGUNTA 5.4:** Resolver ecuación
#
# **R**: Tiempo para recorrer *6KM*
# Usando las funciones:
#     - Metro 0.4t = 6 → 6/0.4 = 15min
#     - Bus 0.3t = 6 → 6/0.3 = 20min
#
# - Para ir desde La Moneda al Costanera Center (~6 km), el metro demora ~15 min, el bus ~20 min.

# %%
#PREGUNTA 5.4: PRACTICA DE FSOLVE
import numpy as np
from scipy.optimize import fsolve

def f(t):
    return 0.4 * t - 6 # metro

def g(t):
    return 0.3 * t - 6  # bus

t= np.linspace(0, 25, 1) #RANGO SIMILAR A ARANGE PERO VALORES QUE PODRIA TOMAR t. NO CONSIDERA ULTIMO ELEMENTO
solucion_f = fsolve(f, t) #primero la funcion, despues la variable independiente
solucion_g = fsolve(g, t) #primero la funcion, despues la variable independiente
print(f"Se demora {solucion_f[0]:.0f} minutos en recorrer 6 kms en Metro") #0 porque queremos solo una solución
print(f"Se demora {solucion_g[0]:.0f} minutos en recorrer 6 kms en Bus") #0 porque queremos solo una solución
# Out:
# Se demora 15 minutos en recorrer 6 kms en Metro
# Se demora 20 minutos en recorrer 6 kms en Bus

# %% [markdown]
# # Problema 6

# %% [markdown]
# La temperatura de un servidor (en °C) puede ser modelada mediante la función
#
# $$T(t) = -0,5 t^{2} + 3 t + 20$$
#
# donde $t$ corresponde al tiempo transcurrido (en horas) en un día laboral. Considere que la jornada laboral comienza a las 08:00 horas y termina a las 17:00 horas.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine el dominio contextualizado del problema.
# 3.  Grafique la función utilizando *Python*.
# 4.  Mediante un análisis gráfico, estime cuándo el servidor alcanza la máxima temperatura y calcule cuánto es.
# 5.  Determine la temperatura del servidor a las 13:00 horas y al finalizar la jornada laboral.

# %% [markdown]
# **Pregunta 6.1: Defina variable dependiente e independiente, indicando unidad de medida.**
#
# - *Variable independiente*: Tiempo en horas
# - *Variable dependiente*: Temperatura en grados celsius

# %% [markdown]
# **Pregunta 6.2: Determine el dominio contextualizado del problema.**
#
# El dominio contextualizado es de 0 hasta 9 (08:00 a 17:00)
# - Dom(t) = [0,9]

# %% [markdown]
# **Pregunta 6.3: Grafique la función utilizando Python**

# %%
import numpy as py
import matplotlib.pyplot as plt

def T(t):
  return -0.5*t**2 + 3*t + 20

t = np.arange(0, 9, 0.1) #Dom(t):[0,9] jornada de 08:00 a 17:00

plt.plot(t, T(t),label= "Tiempo")
plt.legend()
plt.xlabel("Tiempo en horas")
plt.ylabel("Temperatura en C°")
plt.title("Temperatura del servidor")
plt.grid(True)
plt.axis([0,9,0,25])
# Out:
# (np.float64(0.0), np.float64(9.0), np.float64(0.0), np.float64(25.0))

# %% [markdown]
# **Pregunta 6.4: Mediante un análisis gráfico, estime cuándo el servidor alcanza la máxima temperatura y calcule cuánto es.**

# %%
def T(t):
  return -0.5*t**2 + 3*t + 20

print(f"La T es {T(3)}")
print(f"La temperatura máximo ocurre a las 3 horas desde el inicio de la jornada laboral")
# Out:
# La T es 24.5
# La temperatura máximo ocurre a las 3 horas desde el inicio de la jornada laboral

# %% [markdown]
# **Pregunta 6.5: Determine la temperatura del servidor a las 13:00 horas y al finalizar la jornada laboral.**

# %%
def T(t):
  return -0.5*t**2 + 3*t + 20

print(f"A las 13:00, la temperatura será de {T(5)}°C")
print(f"A las 17:00, la temperatura será de {T(9)}°C")
# Out:
# A las 13:00, la temperatura será de 22.5°C
# A las 17:00, la temperatura será de 6.5°C

# %% [markdown]
# # Problema 7

# %% [markdown]
# El número de usuarios de una red social se puede modelar mediante la función:
#
# $$U(t) = \frac{1.000}{1+9e^{-0.5t}}$$
#
# donde $t$ corresponde al tiempo transcurrido en meses.
#
# 1.  Defina variable dependiente e independiente, indicando unidad de medida.
# 2.  Determine la cantidad de usuarios transcurridos $12$ meses.
# 3.  Grafique la función, utilizando la librería *Matplotlib*, para los primeros dos años de funcionamiento.
# 4.  ¿Cuánto tiempo debe pasar para que la red social llegue a $800$ usuarios?

# %% [markdown]
# **Pregunta 7.1: Defina variable dependiente e independiente, indicando unidad de medida.**
#
# - Variable independiente ($t$): tiempo transcurrido en meses
# - Variable dependiente $U$($t$): numero de usuarios de una red social en unidades

# %% [markdown]
# **Pregunta 7.2: Determine la cantidad de usuarios transcurridos 12 meses**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def U(t):
  return 1000/(1 + 9*np.exp(-0.5*t))

print(f"A los 12 meses tendrá {U(12):.0f} usuarios la red social")
# Out:
# A los 12 meses tendrá 978 usuarios la red social

# %% [markdown]
# **Pregunta 7.3: Grafique la función, utilizando la librería *Matplotlib*, para los primeros dos años de funcionamiento.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

def U(t):
  return 1000/(1 + 9*np.exp(-0.5*t))

t = np.arange(0, 24, 0.1) #Dom(t):[0,24] primeros dos años

plt.plot(t, U(t),label= "Tiempo")
plt.legend()
plt.xlabel("Tiempo transcurrido en meses")
plt.ylabel("Numero de usuarios en unidades")
plt.title("Numero de usuarios de una red social")
plt.grid(True)

# %% [markdown]
# **Pregunta 7.4: ¿Cuánto tiempo debe pasar para que la red social llegue a $800$ usuarios?**

# %%
#PREGUNTA 4
import numpy as np
from scipy.optimize import fsolve

def U(t):
  return 1000/(1 + 9*np.exp(-0.5*t))-800 # despejar la ecuación

t= np.linspace(0, 25, 1) # RANGO SIMILAR A ARANGE PERO VALORES QUE PODRIA TOMAR t. NO CONSIDERA ULTIMO ELEMENTO
solucion = fsolve(U, t) # Primero la funcion, despues la variable independiente
print(f"A los {solucion[0]:.1f} meses aproximadamente serán 800 usuarios") #0 porque queremos solo una solución
# Out:
# A los 7.2 meses aproximadamente serán 800 usuarios

# %% [markdown]
# # Problema 8

# %% [markdown]
# El tiempo de ejecución de un algoritmo de ordenación (en segundos) se puede modelar mediante la función:
#
# $$A(n) = 0,01n^{2} + 0,5n + 2$$
#
# donde $n$ corresponde a la cantidad de elementos a ordenar. El algoritmo funciona desde las 23:00 horas hasta las 06:00 horas y debe ordenar $1.562$ elementos.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el dominio contextualizado de la función.
# 3. Determine el tiempo de ejecución para ordenar $1.200$ elementos.
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $A(n)$.
# 5. ¿Cuántos elementos ordena luego de $6$ horas de funcionamiento?

# %% [markdown]
# **Pregunta 8.1:** Defina variable dependiente e independiente, indicando unidad de medida.
#
# Variable independiente:
# - $n$: cantidad de elementos a ordenar (unidades)
#
# Variable independiente:
# - $A(n)$: tiempo de ejecucion de un algoritmo de ordenación (en segundos)

# %% [markdown]
# **Pregunta 8.2:** Determine el dominio contextualizado de la función.
#
# - Restricción horaria: [0, 25200] #7 horas * 60 mins * 60 segs → 25200]
#
# - Dom($n$): [0, 1562] #elementos

# %%
import numpy as np
from scipy.optimize import fsolve

# Función: A(n) - 25200 = 0
def f(n):
    return 0.01*n**2 + 0.5*n + 2 - 25200

# Usamos un valor inicial cercano (2000)
sol = fsolve(f, 2000) # Primero la funcion, despues la variable independiente
print(f"El máximo número de elementos que se puede ordenar es aproximadamente n = {sol[0]:.0f}")
# Out:
# El máximo número de elementos que se puede ordenar es aproximadamente n = 1563

# %% [markdown]
# **Pregunta 8.3:** Determine el tiempo de ejecución para ordenar $1.200$ elementos.

# %%
# Función: A(n)
def f(n):
    return 0.01*n**2 + 0.5*n + 2

variable = 1200
print(f"El tiempo de ejecución para ordenar {variable} elementos es de {f(variable):.0f} ")
# Out:
# El tiempo de ejecución para ordenar 1200 elementos es de 15002

# %% [markdown]
# **Pregunta 8.4:** Grafique, utilizando la biblioteca *Matplotlib*, la función $A(n)$.

# %%
import matplotlib.pyplot as plt
import numpy as np 

# Función: A(n)
def f(n):
    return 0.01*n**2 + 0.5*n + 2

n = np.arange(0, 1562, 0.1)  #np.arange(inicio, fin, paso)

# Graficar funciones
plt.plot(n, f(n), label="Tiempo de ejecución (f(n))")  #dibuja una curva x = t, y = f(t)
plt.axhline(y=25200, color='r', linestyle='--', label="Límite de tiempo (25200 s)")


# Ajustamos los ejes: [xmin, xmax, ymin, ymax]
plt.axis([0, 1600, 0, 30000])  

plt.legend() #muestra la leyenda con los nombres que pusimos en label
plt.xlabel("Cantidad de elementos a ordenar unidades") #nombre del eje x
plt.ylabel("Tiempo de ejecución de un algaritmo en ordenación") #nombre del eje y
plt.title("Tiempo de ejecución de un algoritmo") #título del gráfico
plt.grid(True) #activa la rejilla (cuadrícula) para ver mejor los valores
plt.show() #muestra el grafico. a veces no lo muestra sin este codigo
# Ajustamos los ejes: [xmin, xmax, ymin, ymax]

# %% [markdown]
# **Pregunta 8.5:** ¿Cuántos elementos ordena luego de $6$ horas de funcionamiento?

# %%
import numpy as np
from scipy.optimize import fsolve

# Función: A(n) - 21600 = 0
def f(n):
    return 0.01*n**2 + 0.5*n + 2 - (6*60*60)

# Usamos un valor inicial cercano (2000)
sol = fsolve(f, 1000) # Primero la funcion, despues la variable independiente
print(f"El máximo número de elementos que se puede ordenar es aproximadamente n = {sol[0]:.0f}")
# Out:
# El máximo número de elementos que se puede ordenar es aproximadamente n = 1445

# %% [markdown]
# # Problema 9

# %% [markdown]
# El consumo de energía (en $kWh$) de un *Data Center* puede ser modelado por la función:
#
#  $$E(t) = 50\cdot \log(t + 1) + 200$$
#
# donde $t$ corresponde al tiempo (en horas) desde el inicio del monitoreo.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine el consumo de energía del *Data Center* después de $5$ horas.
# 3. ¿Luego de cuántas horas el consumo será de $350$ kWh?
# 4. Grafique, utilizando la biblioteca *Matplotlib*, la función $E(t)$.

# %% [markdown]
# **Pregunta 9.1:** Defina variable dependiente e independiente, indicando unidad de medida.

# %% [markdown]
# Variable independiente:
# - $t$: tiempo en horas
#
# Variable dependiente:
# - $E(t)$: Consumo de energía de un data center

# %% [markdown]
# **Pregunta 9.2:** Determine el consumo de energía del *Data Center* después de $5$ horas.

# %% [markdown]
# **Pregunta 9.3:** ¿Luego de cuántas horas el consumo será de $350$ kWh?

# %% [markdown]
# **Pregunta 9.4:** Grafique, utilizando la biblioteca *Matplotlib*, la función $E(t)$.

# %% [markdown]
# # Problema 10

# %% [markdown]
# En gestión de proyectos, es crucial entender cómo se distribuye la carga de trabajo a lo largo del tiempo para planificar recursos, tiempo y esfuerzos de manera eficiente. Un fenómeno común es la disminución exponencial de la carga de trabajo, donde el esfuerzo requerido es mayor al inicio del proyecto y disminuye gradualmente a medida que se completan las tareas principales.
#
# Esta disminución exponencial puede modelarse matemáticamente para predecir y gestionar el trabajo de manera efectiva.
#
# <br>
#
# Un estudio sobre gestión de proyectos sostiene que la carga de trabajo en un proyecto (en porcentaje) puede ser modelada por la función:
#
# $$W(t) = 100e^{-0.1t}$$
#
# donde $t$ corresponde al tiempo transcurrido (en semanas) desde el inicio del proyecto.
#
# 1. Defina variable dependiente e independiente, indicando unidad de medida.
# 2. Determine la carga de trabajo al inicio del proyecto.
# 3. ¿Cuál será la carga de trabajo luego de transcurridas $4$ semanas desde el inicio del proyecto?
# 4. Si el proyecto duró $12$ semanas, ¿es correcto afirmar que la carga de trabajo llegó al $20\%$?
# 5. ¿Cuántas semanas han pasado desde el inicio del proyecto para que la carga de trabajo sea de $55\%$?
# 6. Utilizando *Matplotlib*, grafique la función considerando un tiempo máximo de $12$ semanas.
