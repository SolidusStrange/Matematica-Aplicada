# %% [markdown]
# Sea una sucesión cuyos tres primeros términos son 200, 224 y 248. Si la sucesión mantiene el mismo patrón de crecimiento sucesivamente.
# 1) El valor del término que ocupa el lugar 36 en esta sucesión es
# 2) ¿Cuál es la suma de los primeros 36 términos de esta sucesión?

# %%
#1) An = A1 + d(n-1) ARITMETICA
def A(n):
    return 200 + 24*(n-1)

print(A(36))

#2) Suma 36 terminos
suma = 0
lista = []
for n in range(1, 37):
    suma += n

lista.append(suma)

print(lista)
# Out:
# 1040
# [666]

# %% [markdown]
# 3 y 4)Una cuenta de ahorros proporciona un interés mensual del 1,2%. La cuenta se abre con $2.000.000. En este contexto, se define a subíndice n como el saldo en pesos que presenta esta cuenta de ahorros transcurridos n meses.

# %%
#3) La expresión algebraica que permite calcular cada término de la sucesión a subíndice n es:
# An = a1 * r**(n-1)

def A(n):
    return a1 * r**(n-1)

a1 = 2000000
r = 1.012

#4) El saldo aproximado en la cuenta al cabo de 9 meses
print(round(A(9),0))
# Out:
# 2200260.0
